# %% [markdown]
# <a href="https://colab.research.google.com/github/Ernesto23lolxd/POO/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def CalcularDoble(qaz):
    qaz = qaz * 2
    return qaz

# %%
#asignar el resultado de la division de una variable
Valor_al_doble=CalcularDoble(5)
print(Valor_al_doble)

#0 simplemente
print(CalcularDoble(20))
# Out:
# 10
# 40

# %%
# LA VARIABLE variableX no existe, solo existe dentro de la funcion

def elfuncio():
  variableX = 123

  elfuncio()
  print(variableX)

# %%
# el alcance de una variable existente fuera de una funcion solo se
# puede implementar denreo de una funcion cuando su valor es leido.
# El asignar un valir hace que la funcion cree su propia variable

def miFuncion():
  variable = 2
  print("¿valor de la variable", variable)

  variable = 1
  print("valor de la variable", variable)
  miFuncion()
  print("valor de la variable", variable)

# %%
def miFuncion():
  global variable
  print = 2
  print("¿valor de la variable", variable)

  variable = 1
  print("valor de la variable", variable)
  miFuncion()
  print("valor de la variable", variable)
